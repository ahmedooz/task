# %% [markdown]
# # Data Analysis

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import scipy.stats as stats
from scipy.stats import f

# %%
import matplotlib.pyplot as plt

# %%
s_df = pd.read_csv('sales_data_python.csv')

# %%
s_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# ...

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 17 columns):
# ORDERNUMBER        2823 non-null int64
# QUANTITYORDERED    2823 non-null int64
# PRICEEACH          2823 non-null float64
# ORDERLINENUMBER    2823 non-null int64
# SALES              2823 non-null float64
# ORDERDATE          2823 non-null object
# STATUS             2823 non-null object
# QTR_ID             2823 non-null int64
# MONTH_ID           2823 non-null int64
# YEAR_ID            2823 non-null int64
# PRODUCTLINE        2823 non-null object
# MSRP               2823 non-null int64
# PRODUCTCODE        2823 non-null object
# CUSTOMERNAME       2823 non-null object
# CITY               2823 non-null object
# COUNTRY            2823 non-null object
# DEALSIZE           2823 non-null object
# dtypes: float64(2), int64(7), object(8)
# memory usage: 375.1+ KB

# %% [markdown]
# # Data Types

# %%
s_df.dtypes
# Out:
# ORDERNUMBER           int64
# QUANTITYORDERED       int64
# PRICEEACH           float64
# ORDERLINENUMBER       int64
# SALES               float64
# ORDERDATE            object
# STATUS               object
# QTR_ID                int64
# MONTH_ID              int64
# YEAR_ID               int64
# PRODUCTLINE          object
# CUSTOMERNAME         object
# CITY                 object
# COUNTRY              object
# DEALSIZE             object
# Sales Category     category
# dtype: object

# %% [markdown]
# # Data Description (Statistical Summary)

# %%
s_df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID
# count   2823.000000  2823.000000  2823.000000  2823.00000
# mean    3553.889072     2.717676     7.092455  2003.81509
# std     1841.865106     1.203878     3.656633     0.69967
# min      482.130000     1.000000     1.000000  2003.00000
# 25%     2203.430000     2.000000     4.000000  2003.00000
# ...

# %%
s_df.describe(include='all')
# Out:
#          ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count    2823.000000      2823.000000  2823.000000      2823.000000
# unique           NaN              NaN          NaN              NaN
# top              NaN              NaN          NaN              NaN
# freq             NaN              NaN          NaN              NaN
# mean    10258.725115        35.092809    83.658544         6.466171
# std        92.085478         9.741443    20.174277         4.225841
# min     10100.000000         6.000000    26.880000         1.000000
# 25%     10180.000000        27.000000    68.860000         3.000000
# 50%     10262.000000        35.000000    95.700000         6.000000
# 75%     10333.500000        43.000000   100.000000         9.000000
# max     10425.000000        97.000000   100.000000        18.000000
#
#                SALES       ORDERDATE   STATUS       QTR_ID     MONTH_ID  \
# count    2823.000000            2823     2823  2823.000000  2823.000000
# ...

# %% [markdown]
# # Deals size

# %%
deals = s_df.groupby('DEALSIZE').agg({'DEALSIZE':'count'})

# %%
deals
# Out:
#           DEALSIZE
# DEALSIZE
# Large          157
# Medium        1384
# Small         1282

# %% [markdown]
# # General info about the data

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 16 columns):
# ORDERNUMBER        2823 non-null int64
# QUANTITYORDERED    2823 non-null int64
# PRICEEACH          2823 non-null float64
# ORDERLINENUMBER    2823 non-null int64
# SALES              2823 non-null float64
# ORDERDATE          2823 non-null object
# STATUS             2823 non-null object
# QTR_ID             2823 non-null int64
# MONTH_ID           2823 non-null int64
# YEAR_ID            2823 non-null int64
# PRODUCTLINE        2823 non-null object
# CUSTOMERNAME       2823 non-null object
# CITY               2823 non-null object
# COUNTRY            2823 non-null object
# DEALSIZE           2823 non-null object
# Sales Category     2823 non-null category
# dtypes: category(1), float64(2), int64(6), object(7)
# memory usage: 333.8+ KB

# %% [markdown]
# # Box Plot - Annual Sales

# %%
box_plt_sales = sns.boxplot(x='YEAR_ID', y='SALES',data =s_df)

# %% [markdown]
# # Grouping: Quantity of Each product per Customer

# %%
s_test = s_df[['CUSTOMERNAME','PRODUCTLINE','QUANTITYORDERED']]
s_df_group = s_test.groupby(['PRODUCTLINE','CUSTOMERNAME'],as_index =False).mean()

# %%
s_df_group
# Out:
#       PRODUCTLINE                 CUSTOMERNAME  QUANTITYORDERED
# 0    Classic Cars               AV Stores, Co.        33.052632
# 1    Classic Cars                 Alpha Cognac        31.500000
# 2    Classic Cars           Amica Models & Co.        37.250000
# 3    Classic Cars      Anna's Decorations, Ltd        31.000000
# 4    Classic Cars            Atelier graphique        39.000000
# ..            ...                          ...              ...
# 394  Vintage Cars        UK Collectables, Ltd.        40.500000
# 395  Vintage Cars              Vitachrome Inc.        37.750000
# 396  Vintage Cars     Volvo Model Replicas, Co        33.500000
# 397  Vintage Cars  West Coast Collectables Co.        38.222222
# 398  Vintage Cars            giftsbymail.co.uk        31.714286
#
# [399 rows x 3 columns]

# %% [markdown]
# # Pivot table (Grouping: Quantity of Each product per Customer)

# %%
s_df_pivot = s_df_group.pivot(index='CUSTOMERNAME',columns ='PRODUCTLINE')

# %%
s_df_pivot
# Out:
#                             QUANTITYORDERED                                    \
# PRODUCTLINE                    Classic Cars Motorcycles     Planes      Ships
# CUSTOMERNAME
# AV Stores, Co.                    33.052632         NaN        NaN  36.714286
# Alpha Cognac                      31.500000         NaN  36.333333  35.285714
# Amica Models & Co.                37.250000         NaN        NaN  27.333333
# Anna's Decorations, Ltd           31.000000   36.500000        NaN        NaN
# Atelier graphique                 39.000000   35.500000        NaN        NaN
# ...                                     ...         ...        ...        ...
# Vida Sport, Ltd                   34.774194         NaN        NaN        NaN
# Vitachrome Inc.                   34.142857   26.555556        NaN        NaN
# Volvo Model Replicas, Co          28.750000         NaN        NaN  40.000000
# West Coast Collectables Co.       35.000000         NaN  43.000000        NaN
# ...

# %% [markdown]
# # ANOVA

# %%
df_anova=s_df[['PRODUCTLINE','PRICEEACH']]
grouped_anova = df_anova.groupby(['PRODUCTLINE'])
anova_result1=stats.f_oneway(grouped_anova.get_group('Motorcycles')['PRICEEACH'],grouped_anova.get_group('Ships')['PRICEEACH'])

# %%
anova_result1
#between Motorcycle price Vs. Ships Price
# Out:
# F_onewayResult(statistic=0.29670135562546573, pvalue=0.5861734873090878)

# %% [markdown]
# The prices between Motorcycles and Ships are NOT significantly different.
#
# Note: This done as an example only - Although this piece of analysis (this case) is not relatively important, but we can use it in different scenarios to obtain much more value.
